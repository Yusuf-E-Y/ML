# %%
import torch

# %%
matrix = torch.randint(10,40,(2,3))
matrix
# Out:
# tensor([[37, 28, 33],
#         [28, 19, 24]])

# %%
# Toplama
# Çıkarma
# Çarpma
# Bölme
# Üs alma
# Cebirsel çarpım

# %% [markdown]
# ### Toplama

# %%
scalar_sum = matrix + 10
scalar_sum
# Out:
# tensor([[38, 32, 26],
#         [46, 22, 25]])

# %% [markdown]
# ### Çıkarma

# %%
scalar_sub = matrix - 10
scalar_sub
# Out:
# tensor([[18, 12,  6],
#         [26,  2,  5]])

# %% [markdown]
# ### Çarpma

# %%
scalar_mul = matrix * 10
scalar_mul
# Out:
# tensor([[280, 220, 160],
#         [360, 120, 150]])

# %% [markdown]
# ### Bölme

# %%
scalar_div = matrix / 2
scalar_div
# Out:
# tensor([[14.0000, 11.0000,  8.0000],
#         [18.0000,  6.0000,  7.5000]])

# %% [markdown]
# ### Üs Alma

# %%
scalar_exp = matrix ** 2
scalar_exp
# Out:
# tensor([[ 784,  484,  256],
#         [1296,  144,  225]])

# %% [markdown]
# ## Tensorler Arası İşlemler

# %%
matrix2 = torch.randint(1,10,(2,3))
matrix2, matrix
# Out:
# (tensor([[1, 6, 7],
#          [9, 3, 4]]),
#  tensor([[37, 28, 33],
#          [28, 19, 24]]))

# %% [markdown]
# ### Tensor Toplama

# %%
tensor_sum = matrix2 + matrix
#tensor_sum = torch.add(matrix, matrix2)
tensor_sum
# Out:
# tensor([[31, 31, 22],
#         [37, 20, 24]])

# %% [markdown]
# ### Tensor Çıkarma

# %%
tensor_sub = matrix - matrix2
#tensor_sub = torch.sub(matrix, matrix2)
tensor_sub
# Out:
# tensor([[25, 13, 10],
#         [35,  4,  6]])

# %% [markdown]
# ### Tensor Çarpma

# %%
tensor_mul = matrix * matrix2
#tensor_mul = torch.mul(matrix, matrix2)
tensor_mul

# %% [markdown]
# ### Cebirsel Çarpma

# %%
algebric_mul = torch.matmul(matrix, matrix2.T) #matrix2.T matrixin devriğini alır çünkü cebirsel çarpma için gereklidir
#algebric_mul = matrix @ matrix2.T
algebric_mul
# Out:
# tensor([[436, 549],
#         [310, 405]])

# %%
tensor_div = matrix / matrix2
#tensor_div = torch.div(matrix, matrix2)
tensor_div
# Out:
# tensor([[37.0000,  4.6667,  4.7143],
#         [ 3.1111,  6.3333,  6.0000]])
